# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("pop.csv", index_col=0)

# %%
data
# Out:
#         smooth         pop       accen        morn       drama      crunch  \
# 0    94.468701  334.904345  248.811886  366.359458  472.570570  668.566315
# 1   165.985892  335.418199  324.522970  417.046309  559.556790  738.141613
# 2    59.926238  358.649676  285.124068  253.759291  596.420169  395.544760
# 3    98.088551  408.933832  305.133218  326.859417  514.865261  499.546275
# 4   181.479883  235.339706  155.584482  466.677163  493.917314  524.311895
# 5   211.644536  247.770063  192.953366  552.849333  478.891579  703.395275
# 6    74.754391  202.154117  208.243362  225.005744  472.960522  310.516830
# 7   309.332025  247.387756  157.974232  624.865792  448.932319  619.258914
# 8    70.638647  102.057125   91.685637  174.769270  214.942812  269.397936
# 9    60.199825  314.142660  246.575370  247.619099  470.016317  457.286023
# 10   94.962600  286.994357  242.924987  356.373203  440.241776  524.425811
# ...

# %%
#data={'org': dist_org_smooth, 'accent': dist_org_pop, 'smooth': dist_org_accen,
      #'morn': dist_org_morn, 'drama': dist_org_drama,'crunch': dist_org_crunch, 'korn': dist_org_korn,
      #'retro': dist_org_retro, 'vintage': dist_org_vintag}
fig = plt.figure(figsize = (50,50))

fig, ax = plt.subplots()
ax.boxplot(data)
plt.ylabel("dist")
ax.set_xticklabels(data.keys())
plt.show()

# %%
fig.savefig('pop.png')
