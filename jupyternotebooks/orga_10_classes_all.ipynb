# %%
#https://docs.python.org/3/library/glob.html
import itertools
import os
import shutil
import random
import glob

# %%
# Organize data into train, valid, test dirs for all data
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/smooth')
    os.makedirs('train/pop')
    os.makedirs('train/accentuate')
    os.makedirs('train/morning')
    os.makedirs('train/DramaDark')
    os.makedirs('train/Vintage')
    os.makedirs('train/Retrolux8')
    os.makedirs('train/Crunch3')
    os.makedirs('train/Kornung104')
   
    train_size = 1000
    valid_size = 150
    test_size = 100
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_size):
        shutil.move(i, 'train/smooth')
    for i in random.sample(glob.glob('*-03*'), train_size):
        shutil.move(i, 'train/pop')        
    for i in random.sample(glob.glob('*-04*'), train_size):
        shutil.move(i, 'train/accentuate')
    for i in random.sample(glob.glob('*-05*'), train_size):
        shutil.move(i, 'train/morning')      
    for i in random.sample(glob.glob('*-06*'), train_size):
        shutil.move(i, 'train/DramaDark')
    for i in random.sample(glob.glob('*-07*'), train_size):
        shutil.move(i, 'train/Vintage')
    for i in random.sample(glob.glob('*-08*'), train_size):
        shutil.move(i, 'train/Retrolux8')
    for i in random.sample(glob.glob('*-09*'), train_size):
        shutil.move(i, 'train/Crunch3')
    for i in random.sample(glob.glob('*-10*'), train_size):
        shutil.move(i, 'train/Kornung104')

        
os.chdir('../../')

# %%
# Organize data into train, valid, test dirs for all data
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/smooth')
    os.makedirs('train/pop')
    os.makedirs('train/accentuate')
    os.makedirs('train/morning')
    os.makedirs('train/DramaDark')
    os.makedirs('train/Vintage')
    os.makedirs('train/Retrolux8')
    os.makedirs('train/Crunch3')
    os.makedirs('train/Kornung104')
    os.makedirs('valid/original')
    os.makedirs('valid/smooth')
    os.makedirs('valid/pop')
    os.makedirs('valid/accentuate')
    os.makedirs('valid/morning')
    os.makedirs('valid/DramaDark')
    os.makedirs('valid/Vintage')
    os.makedirs('valid/Retrolux8')
    os.makedirs('valid/Crunch3')
    os.makedirs('valid/Kornung104')
    os.makedirs('test/original')
    os.makedirs('test/smooth')
    os.makedirs('test/pop')
    os.makedirs('test/accentuate')
    os.makedirs('test/morning')
    os.makedirs('test/DramaDark')
    os.makedirs('test/Vintage')
    os.makedirs('test/Retrolux8')
    os.makedirs('test/Crunch3')
    os.makedirs('test/Kornung104')

    train_size = 750
    valid_size = 150
    test_size = 100
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_size):
        shutil.move(i, 'train/smooth')
    for i in random.sample(glob.glob('*-03*'), train_size):
        shutil.move(i, 'train/pop')        
    for i in random.sample(glob.glob('*-04*'), train_size):
        shutil.move(i, 'train/accentuate')
    for i in random.sample(glob.glob('*-05*'), train_size):
        shutil.move(i, 'train/morning')      
    for i in random.sample(glob.glob('*-06*'), train_size):
        shutil.move(i, 'train/DramaDark')
    for i in random.sample(glob.glob('*-07*'), train_size):
        shutil.move(i, 'train/Vintage')
    for i in random.sample(glob.glob('*-08*'), train_size):
        shutil.move(i, 'train/Retrolux8')
    for i in random.sample(glob.glob('*-09*'), train_size):
        shutil.move(i, 'train/Crunch3')
    for i in random.sample(glob.glob('*-10*'), train_size):
        shutil.move(i, 'train/Kornung104')

    for i in random.sample(glob.glob('*-01*'), valid_size):
        shutil.move(i, 'valid/original')      
    for i in random.sample(glob.glob('*-02*'), valid_size):
        shutil.move(i, 'valid/smooth')
    for i in random.sample(glob.glob('*-03*'), valid_size):
        shutil.move(i, 'valid/pop')        
    for i in random.sample(glob.glob('*-04*'), valid_size):
        shutil.move(i, 'valid/accentuate')
    for i in random.sample(glob.glob('*-05*'), valid_size):
        shutil.move(i, 'valid/morning')      
    for i in random.sample(glob.glob('*-06*'), valid_size):
        shutil.move(i, 'valid/DramaDark')
    for i in random.sample(glob.glob('*-07*'), valid_size):
        shutil.move(i, 'valid/Vintage')
    for i in random.sample(glob.glob('*-08*'), valid_size):
        shutil.move(i, 'valid/Retrolux8')
    for i in random.sample(glob.glob('*-09*'), valid_size):
        shutil.move(i, 'valid/Crunch3')
    for i in random.sample(glob.glob('*-10*'), valid_size):
        shutil.move(i, 'valid/Kornung104')

    for i in random.sample(glob.glob('*-01*'), test_size):
        shutil.move(i, 'test/original')      
    for i in random.sample(glob.glob('*-02*'), test_size):
        shutil.move(i, 'test/smooth')
    for i in random.sample(glob.glob('*-03*'), test_size):
        shutil.move(i, 'test/pop')        
    for i in random.sample(glob.glob('*-04*'), test_size):
        shutil.move(i, 'test/accentuate')
    for i in random.sample(glob.glob('*-05*'), test_size):
        shutil.move(i, 'test/morning')      
    for i in random.sample(glob.glob('*-06*'), test_size):
        shutil.move(i, 'test/DramaDark')
    for i in random.sample(glob.glob('*-07*'), test_size):
        shutil.move(i, 'test/Vintage')
    for i in random.sample(glob.glob('*-08*'), test_size):
        shutil.move(i, 'test/Retrolux8')
    for i in random.sample(glob.glob('*-09*'), test_size):
        shutil.move(i, 'test/Crunch3')
    for i in random.sample(glob.glob('*-10*'), test_size):
        shutil.move(i, 'test/Kornung104')
    

        
os.chdir('../../')

# %%
# Organize data into train, valid, test dirs for a small sample size
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/smooth')
    os.makedirs('train/pop')
    os.makedirs('train/accentuate')
    os.makedirs('train/morning')
    os.makedirs('train/DramaDark')
    os.makedirs('train/Vintage')
    os.makedirs('train/Retrolux8')
    os.makedirs('train/Crunch3')
    os.makedirs('train/Kornung104')
    os.makedirs('valid/original')
    os.makedirs('valid/smooth')
    os.makedirs('valid/pop')
    os.makedirs('valid/accentuate')
    os.makedirs('valid/morning')
    os.makedirs('valid/DramaDark')
    os.makedirs('valid/Vintage')
    os.makedirs('valid/Retrolux8')
    os.makedirs('valid/Crunch3')
    os.makedirs('valid/Kornung104')
    os.makedirs('test/original')
    os.makedirs('test/smooth')
    os.makedirs('test/pop')
    os.makedirs('test/accentuate')
    os.makedirs('test/morning')
    os.makedirs('test/DramaDark')
    os.makedirs('test/Vintage')
    os.makedirs('test/Retrolux8')
    os.makedirs('test/Crunch3')
    os.makedirs('test/Kornung104')

    train_size = 100
    valid_size = 20
    test_size = 10
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_size):
        shutil.move(i, 'train/smooth')
    for i in random.sample(glob.glob('*-03*'), train_size):
        shutil.move(i, 'train/pop')        
    for i in random.sample(glob.glob('*-04*'), train_size):
        shutil.move(i, 'train/accentuate')
    for i in random.sample(glob.glob('*-05*'), train_size):
        shutil.move(i, 'train/morning')      
    for i in random.sample(glob.glob('*-06*'), train_size):
        shutil.move(i, 'train/DramaDark')
    for i in random.sample(glob.glob('*-07*'), train_size):
        shutil.move(i, 'train/Vintage')
    for i in random.sample(glob.glob('*-08*'), train_size):
        shutil.move(i, 'train/Retrolux8')
    for i in random.sample(glob.glob('*-09*'), train_size):
        shutil.move(i, 'train/Crunch3')
    for i in random.sample(glob.glob('*-10*'), train_size):
        shutil.move(i, 'train/Kornung104')

    for i in random.sample(glob.glob('*-01*'), valid_size):
        shutil.move(i, 'valid/original')      
    for i in random.sample(glob.glob('*-02*'), valid_size):
        shutil.move(i, 'valid/smooth')
    for i in random.sample(glob.glob('*-03*'), valid_size):
        shutil.move(i, 'valid/pop')        
    for i in random.sample(glob.glob('*-04*'), valid_size):
        shutil.move(i, 'valid/accentuate')
    for i in random.sample(glob.glob('*-05*'), valid_size):
        shutil.move(i, 'valid/morning')      
    for i in random.sample(glob.glob('*-06*'), valid_size):
        shutil.move(i, 'valid/DramaDark')
    for i in random.sample(glob.glob('*-07*'), valid_size):
        shutil.move(i, 'valid/Vintage')
    for i in random.sample(glob.glob('*-08*'), valid_size):
        shutil.move(i, 'valid/Retrolux8')
    for i in random.sample(glob.glob('*-09*'), valid_size):
        shutil.move(i, 'valid/Crunch3')
    for i in random.sample(glob.glob('*-10*'), valid_size):
        shutil.move(i, 'valid/Kornung104')

    for i in random.sample(glob.glob('*-01*'), test_size):
        shutil.move(i, 'test/original')      
    for i in random.sample(glob.glob('*-02*'), test_size):
        shutil.move(i, 'test/smooth')
    for i in random.sample(glob.glob('*-03*'), test_size):
        shutil.move(i, 'test/pop')        
    for i in random.sample(glob.glob('*-04*'), test_size):
        shutil.move(i, 'test/accentuate')
    for i in random.sample(glob.glob('*-05*'), test_size):
        shutil.move(i, 'test/morning')      
    for i in random.sample(glob.glob('*-06*'), test_size):
        shutil.move(i, 'test/DramaDark')
    for i in random.sample(glob.glob('*-07*'), test_size):
        shutil.move(i, 'test/Vintage')
    for i in random.sample(glob.glob('*-08*'), test_size):
        shutil.move(i, 'test/Retrolux8')
    for i in random.sample(glob.glob('*-09*'), test_size):
        shutil.move(i, 'test/Crunch3')
    for i in random.sample(glob.glob('*-10*'), test_size):
        shutil.move(i, 'test/Kornung104')
    

        
os.chdir('../../')
