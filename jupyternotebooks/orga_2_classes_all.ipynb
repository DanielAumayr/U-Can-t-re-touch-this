# %%
import itertools
import os
import shutil
import random
import glob

# %%
# Organize data into train, valid, test dirs for all data processed and orgiginal have same ammount of pictures
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/processed')
    os.makedirs('valid/original')
    os.makedirs('valid/processed')
    os.makedirs('test/original')
    os.makedirs('test/processed')
    
    train_size = 765
    train_processed_size = 85
    valid_size = 135
    valid_processed_size = 15
    test_size = 99
    test_processed_size = 11 
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-03*'), train_processed_size):
        shutil.move(i, 'train/processed')        
    for i in random.sample(glob.glob('*-04*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-05*'), train_processed_size):
        shutil.move(i, 'train/processed')      
    for i in random.sample(glob.glob('*-06*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-07*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-08*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-09*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-10*'), train_processed_size):
        shutil.move(i, 'train/processed')

    for i in random.sample(glob.glob('*-01*'), valid_size):
        shutil.move(i, 'valid/original')      
    for i in random.sample(glob.glob('*-02*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-03*'), valid_processed_size):
        shutil.move(i, 'valid/processed')        
    for i in random.sample(glob.glob('*-04*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-05*'), valid_processed_size):
        shutil.move(i, 'valid/processed')      
    for i in random.sample(glob.glob('*-06*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-07*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-08*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-09*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-10*'), valid_processed_size):
        shutil.move(i, 'valid/processed')

    for i in random.sample(glob.glob('*-01*'), test_size):
        shutil.move(i, 'test/original')      
    for i in random.sample(glob.glob('*-02*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-03*'), test_processed_size):
        shutil.move(i, 'test/processed')        
    for i in random.sample(glob.glob('*-04*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-05*'), test_processed_size):
        shutil.move(i, 'test/processed')      
    for i in random.sample(glob.glob('*-06*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-07*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-08*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-09*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-10*'), test_processed_size):
        shutil.move(i, 'test/processed')
    

        
os.chdir('../../')

# %%
# Organize data into train, valid, test dirs for all data more processed pictures than original
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/processed')
    os.makedirs('valid/original')
    os.makedirs('valid/processed')
    os.makedirs('test/original')
    os.makedirs('test/processed')
    
    train_size = 750
    train_processed_size = 250
    valid_size = 150
    valid_processed_size = 50
    test_size = 100
    test_processed_size = 34 
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-03*'), train_processed_size):
        shutil.move(i, 'train/processed')        
    for i in random.sample(glob.glob('*-04*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-05*'), train_processed_size):
        shutil.move(i, 'train/processed')      
    for i in random.sample(glob.glob('*-06*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-07*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-08*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-09*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-10*'), train_processed_size):
        shutil.move(i, 'train/processed')

    for i in random.sample(glob.glob('*-01*'), valid_size):
        shutil.move(i, 'valid/original')      
    for i in random.sample(glob.glob('*-02*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-03*'), valid_processed_size):
        shutil.move(i, 'valid/processed')        
    for i in random.sample(glob.glob('*-04*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-05*'), valid_processed_size):
        shutil.move(i, 'valid/processed')      
    for i in random.sample(glob.glob('*-06*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-07*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-08*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-09*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-10*'), valid_processed_size):
        shutil.move(i, 'valid/processed')

    for i in random.sample(glob.glob('*-01*'), test_size):
        shutil.move(i, 'test/original')      
    for i in random.sample(glob.glob('*-02*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-03*'), test_processed_size):
        shutil.move(i, 'test/processed')        
    for i in random.sample(glob.glob('*-04*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-05*'), test_processed_size):
        shutil.move(i, 'test/processed')      
    for i in random.sample(glob.glob('*-06*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-07*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-08*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-09*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-10*'), test_processed_size):
        shutil.move(i, 'test/processed')
    

        
os.chdir('../../')

# %%
# Organize data into train, valid, test dirs for all data processed and orgiginal have same ammount of pictures
# with a small sample size for testing purposes
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/processed')
    os.makedirs('valid/original')
    os.makedirs('valid/processed')
    os.makedirs('test/original')
    os.makedirs('test/processed')
    
    train_size = 108
    train_processed_size = 12
    valid_size = 27
    valid_processed_size = 3
    test_size = 18
    test_processed_size = 2 
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-03*'), train_processed_size):
        shutil.move(i, 'train/processed')        
    for i in random.sample(glob.glob('*-04*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-05*'), train_processed_size):
        shutil.move(i, 'train/processed')      
    for i in random.sample(glob.glob('*-06*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-07*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-08*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-09*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-10*'), train_processed_size):
        shutil.move(i, 'train/processed')

    for i in random.sample(glob.glob('*-01*'), valid_size):
        shutil.move(i, 'valid/original')      
    for i in random.sample(glob.glob('*-02*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-03*'), valid_processed_size):
        shutil.move(i, 'valid/processed')        
    for i in random.sample(glob.glob('*-04*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-05*'), valid_processed_size):
        shutil.move(i, 'valid/processed')      
    for i in random.sample(glob.glob('*-06*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-07*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-08*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-09*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-10*'), valid_processed_size):
        shutil.move(i, 'valid/processed')

    for i in random.sample(glob.glob('*-01*'), test_size):
        shutil.move(i, 'test/original')      
    for i in random.sample(glob.glob('*-02*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-03*'), test_processed_size):
        shutil.move(i, 'test/processed')        
    for i in random.sample(glob.glob('*-04*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-05*'), test_processed_size):
        shutil.move(i, 'test/processed')      
    for i in random.sample(glob.glob('*-06*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-07*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-08*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-09*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-10*'), test_processed_size):
        shutil.move(i, 'test/processed')
    

        
os.chdir('../../')

# %%
# Organize data into train, valid, test dirs for all data more processed pictures than original
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/processed')
    os.makedirs('valid/original')
    os.makedirs('valid/processed')
    os.makedirs('test/original')
    os.makedirs('test/processed')
    
    train_size = 99
    train_processed_size = 33
    valid_size = 15
    valid_processed_size = 5
    test_size = 12
    test_processed_size = 4 
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-03*'), train_processed_size):
        shutil.move(i, 'train/processed')        
    for i in random.sample(glob.glob('*-04*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-05*'), train_processed_size):
        shutil.move(i, 'train/processed')      
    for i in random.sample(glob.glob('*-06*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-07*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-08*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-09*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-10*'), train_processed_size):
        shutil.move(i, 'train/processed')

    for i in random.sample(glob.glob('*-01*'), valid_size):
        shutil.move(i, 'valid/original')      
    for i in random.sample(glob.glob('*-02*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-03*'), valid_processed_size):
        shutil.move(i, 'valid/processed')        
    for i in random.sample(glob.glob('*-04*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-05*'), valid_processed_size):
        shutil.move(i, 'valid/processed')      
    for i in random.sample(glob.glob('*-06*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-07*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-08*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-09*'), valid_processed_size):
        shutil.move(i, 'valid/processed')
    for i in random.sample(glob.glob('*-10*'), valid_processed_size):
        shutil.move(i, 'valid/processed')

    for i in random.sample(glob.glob('*-01*'), test_size):
        shutil.move(i, 'test/original')      
    for i in random.sample(glob.glob('*-02*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-03*'), test_processed_size):
        shutil.move(i, 'test/processed')        
    for i in random.sample(glob.glob('*-04*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-05*'), test_processed_size):
        shutil.move(i, 'test/processed')      
    for i in random.sample(glob.glob('*-06*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-07*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-08*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-09*'), test_processed_size):
        shutil.move(i, 'test/processed')
    for i in random.sample(glob.glob('*-10*'), test_processed_size):
        shutil.move(i, 'test/processed')
    

        
os.chdir('../../')

# %%
# Organize data into train, valid, test dirs for all data processed and orgiginal have same ammount of pictures
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/processed')
    
    train_size = 1000
    train_processed_size = 161
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    for i in random.sample(glob.glob('*-02*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-03*'), train_processed_size):
        shutil.move(i, 'train/processed')        
    for i in random.sample(glob.glob('*-04*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-05*'), train_processed_size):
        shutil.move(i, 'train/processed')      
    for i in random.sample(glob.glob('*-06*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-07*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-08*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-09*'), train_processed_size):
        shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-10*'), train_processed_size):
        shutil.move(i, 'train/processed')

    

        
os.chdir('../../')

# %%
# Organize data into train, valid, test dirs for all data processed and orgiginal have same ammount of pictures
os.chdir('C:/Users/Daniel/Documents/MCI/bach/jupyter/data_2/bearbeitet')
if os.path.isdir('train/original') is False:
    os.makedirs('train/original')
    os.makedirs('train/processed')
    
    train_size = 1000
    train_processed_size = 1000
    
    for i in random.sample(glob.glob('*-01*'), train_size):
        shutil.move(i, 'train/original')      
    #for i in random.sample(glob.glob('*-02*'), train_processed_size):
    #    shutil.move(i, 'train/processed')
    for i in random.sample(glob.glob('*-03*'), train_processed_size):
        shutil.move(i, 'train/processed')        
    #for i in random.sample(glob.glob('*-04*'), train_processed_size):
    #    shutil.move(i, 'train/processed')
    #for i in random.sample(glob.glob('*-05*'), train_processed_size):
    #    shutil.move(i, 'train/processed')      
    #for i in random.sample(glob.glob('*-06*'), train_processed_size):
    #    shutil.move(i, 'train/processed')
    #for i in random.sample(glob.glob('*-07*'), train_processed_size):
    #    shutil.move(i, 'train/processed')
    #for i in random.sample(glob.glob('*-08*'), train_processed_size):
    #    shutil.move(i, 'train/processed')
    #for i in random.sample(glob.glob('*-09*'), train_processed_size):
    #    shutil.move(i, 'train/processed')
    #for i in random.sample(glob.glob('*-10*'), train_processed_size):
    #    shutil.move(i, 'train/processed')

    

        
os.chdir('../../')
